# %%
import firebase_admin
from firebase_admin import credentials
from firebase_admin import db
import requests
from pprint import pprint

import pandas as pd
# %matplotlib inline

import config


# Fetch the service account key JSON file contents
cred = credentials.Certificate(config.firebase_file_path)
# Initialize the app with a service account, granting admin privileges
firebase_admin.initialize_app(cred, {
    'databaseURL': config.databaseURL
})

# %%
#Imports
import pandas as pd
import numpy as np
from scipy.stats import beta

# %%
#Get data from database
listingStatsDB  = "listing_stats.json"
r = requests.get(config.databaseURL + listingStatsDB)
r = r.json()
# style_in_html = ""
# data_in_html = ""
if r:
    data = [r[i] for i in r]
    listing_stats_df = pd.DataFrame.from_dict(data, orient='columns')

listing_stats_df = listing_stats_df.astype({"listingID": int,"revenue":float,"sold":int,"visits":int})

    
listing_stats_df.sample(20)
# Out:
#       listingID record_date  revenue  sold  visits
# 2574  680077296  2019-07-25      0.0     0       0
# 2781  702303569  2019-08-10      0.0     0       0
# 768   680077296     6/12/19      0.0     0       1
# 2162  693930997     7/12/19      0.0     0       1
# 207   701339360      7/2/19      0.0     0       1
# 2338  706002567     7/18/19      0.0     0       0
# 1162  680082346     5/25/19      0.0     0       0
# 426   680079806     6/25/19      0.0     0       1
# 758   691796412     6/12/19      0.0     0       0
# 3028  721874971  2019-08-19      0.0     0       0
# 2855  693930997  2019-08-13      0.0     0       1
# 1802  680071910     4/21/19      0.0     0       0
# 1605  680071910      5/4/19      0.0     0       0
# 712   693933847     6/14/19      0.0     0       0
# 2252  688465922     7/15/19      0.0     0       0
# 714   691796412     6/14/19      0.0     0       1
# 2866  685744834  2019-08-13      0.0     0       0
# 1751  680069172     4/25/19      0.0     0       0
# 1896  693930997     4/13/19      0.0     0      16
# 308   680084324     6/29/19      0.0     0       2

# %%
listing_stats_df.dtypes
# Out:
# listingID        int64
# record_date     object
# revenue        float64
# sold             int64
# visits           int64
# dtype: object

# %%
#Get data from database
listingCreationDB  = "listing_creation_dates.json"
r = requests.get(config.databaseURL + listingCreationDB)
r = r.json()
# style_in_html = ""
# data_in_html = ""
if r:
    data = [r[i] for i in r]
    listing_creation_df = pd.DataFrame.from_dict(data, orient='columns')

listing_creation_df = listing_creation_df.astype({"ListingID": int})

listing_creation_df.head()
# Out:
#    ListingID OriginallyCreated
# 0  680077296        2019-03-26
# 1  680079806        2019-03-26
# 2  680082346        2019-03-26
# 3  680084324        2019-03-26
# 4  680085112        2019-03-27

# %%
listing_creation_df=listing_creation_df.drop_duplicates()

# %%
listing_creation_df['OriginallyCreated'] = pd.to_datetime(listing_creation_df['OriginallyCreated'])
listing_creation_df.dtypes
# Out:
# ListingID                     int64
# OriginallyCreated    datetime64[ns]
# dtype: object

# %%
#Get data from database
activeListingsDB  = "active_listings.json"
r = requests.get(config.databaseURL + activeListingsDB)
r = r.json()
# style_in_html = ""
# data_in_html = ""
if r:
    data = [r[i] for i in r]
    active_listings_df = pd.DataFrame.from_dict(data, orient='columns')

active_listings_df = active_listings_df.astype({"listingID": int})

active_listings_df.head()
# Out:
#    listingID
# 0  687898920
# 1  701341356
# 2  685451744
# 3  680071910
# 4  680079806

# %%
from datetime import datetime, date, time, timedelta


listingIDs=active_listings_df['listingID']
from pytz import timezone

now = datetime.now()
now = timezone('US/Central').localize(now)


listingIDsAll=[]
creationDateAll=[]
listingViewsAll=[]
totalSiteViewsAll=[]
avg_views_day=[]
max_views_day=[]
min_views_day=[]
editURLs=[]
daysActive=[]

for listing in listingIDs:
    #sort listing stats by listing
    listingIDsAll.append(listing)
    
    editURL=(f'https://www.etsy.com/your/shops/jetchcreations/tools/listings/view:table,stats:true/{listing}')
    editURLs.append(editURL)
    
    stats_by_listing=listing_stats_df.loc[listing_stats_df['listingID']==listing,:]
    
    #find the sum of views for the listing
    listingViews = stats_by_listing['visits'].sum()
    listingViewsAll.append(listingViews)
    
    #find the creation date for listing
    creation_date_by_listings=listing_creation_df.loc[listing_creation_df['ListingID']==listing,:]
    creation_date_by_listings=creation_date_by_listings.reset_index(drop=True)
    creationDate=creation_date_by_listings['OriginallyCreated'][0]
    creationDate = timezone('US/Central').localize(creationDate)
    creationDate =creationDate + timedelta(hours=5)
    creationDateAll.append(creationDate)
    
    noDaysSinceCreation= now - creationDate

    noDaysSinceCreation = noDaysSinceCreation/ np.timedelta64(1, 'D')

    daysActive.append(noDaysSinceCreation)
    
    #find total site views since the listing was created
    for index, item in listing_stats_df.iterrows():
        try:
            record_date = datetime.strptime(item.record_date, "%m/%d/%y")
            record_date = timezone('US/Central').localize(record_date)

            record_date =record_date + timedelta(hours=5)

            listing_stats_df.loc[index,'record_date_local']=record_date
        except:
            record_date = datetime.strptime(item.record_date, "%Y-%m-%d")
            record_date = timezone('US/Central').localize(record_date)

            record_date =record_date + timedelta(hours=5)

            listing_stats_df.loc[index,'record_date_local']=record_date
    
    total_views_since_creation=listing_stats_df.loc[listing_stats_df['record_date_local']>=creationDate]
    
    #find the sum of views for the listing
    total_views_since_creation = total_views_since_creation.astype({"visits": int})

    totalSiteViews = total_views_since_creation['visits'].sum()
    totalSiteViewsAll.append(totalSiteViews)
    
    averageViewsPerListingPerDay = 0.85
    averageViewsPerDay = 28.5
    
    averageViewsPerListingPerDay/averageViewsPerDay
    
    priorScale = 7 #one week
    priorAlpha = averageViewsPerListingPerDay * priorScale #average views per listing per day (success)
    priorBeta = (averageViewsPerDay * priorScale) - priorAlpha #average total views per day minus average listing views (failures)

    scale = 1 #scale to make graph pretty

    posteriorAlpha = priorAlpha + listingViews
    posteriorBeta = priorBeta + (totalSiteViews - listingViews)
    
    
    ntrials = 10000
    sample = beta.rvs(posteriorAlpha, posteriorBeta, scale=scale, size=ntrials)
    
    avg_views_day1=(np.mean(sample)/scale) * averageViewsPerDay
    avg_views_day.append(avg_views_day1)
    min_views_day1=(np.quantile(sample, .025)/ scale) * averageViewsPerDay
    min_views_day.append(min_views_day1)
    max_views_day1=(np.quantile(sample, .975)/ scale) * averageViewsPerDay
    max_views_day.append(max_views_day1)
    
bayes_df=pd.DataFrame({'listingID':listingIDsAll,
'creationDate':creationDateAll,
'listingViews':listingViewsAll,
'totalSiteViews':totalSiteViewsAll,
'avg_views_day':avg_views_day,
'max_views_day':max_views_day,
'min_views_day':min_views_day,
'edit_url':editURLs,
'days_active':daysActive})

bayes_df["curr_views_day"] = (bayes_df.listingViews / bayes_df.totalSiteViews) * 28.5
bayes_df
# Out:
#     listingID              creationDate  listingViews  totalSiteViews  \
# 0   687898920 2019-04-26 05:00:00-05:00           499            3110
# 1   701341356 2019-06-18 05:00:00-05:00            83            1445
# 2   685451744 2019-04-16 05:00:00-05:00           136            3340
# 3   680071910 2019-03-26 05:00:00-05:00           180            3739
# 4   680079806 2019-03-26 05:00:00-05:00           203            3739
# 5   712179258 2019-08-02 05:00:00-05:00             1             286
# 6   712150418 2019-08-02 05:00:00-05:00             1             286
# 7   693930997 2019-03-26 05:00:00-05:00           417            3739
# 8   701210678 2019-06-18 05:00:00-05:00            15            1445
# 9   680064082 2019-03-26 05:00:00-05:00          1140            3739
# 10  701339360 2019-06-18 05:00:00-05:00            99            1445
# 11  721881161 2019-07-16 05:00:00-05:00             2             540
# 12  721879701 2019-07-16 05:00:00-05:00             2             540
# 13  721874971 2019-07-16 05:00:00-05:00             3             540
# 14  707973152 2019-07-16 05:00:00-05:00            13             540
# 15  701344590 2019-06-18 05:00:00-05:00            35            1445
# 16  701202082 2019-06-18 05:00:00-05:00            57            1445
# 17  702303569 2019-04-28 05:00:00-05:00            41            3101
# 18  685744834 2019-04-17 05:00:00-05:00             2            3304
# 19  700382982 2019-06-14 05:00:00-05:00            43            1581
# 20  700377146 2019-06-14 05:00:00-05:00            19            1581
# 21  691796412 2019-05-11 05:00:00-05:00            26            2629
# 22  704569159 2019-05-07 05:00:00-05:00            24            2768
# 23  690717354 2019-05-07 05:00:00-05:00            10            2768
# 24  703387331 2019-05-02 05:00:00-05:00            25            2952
# 25  688465922 2019-04-28 05:00:00-05:00            87            3101
# 26  688443618 2019-04-28 05:00:00-05:00            44            3101
#
#     avg_views_day  max_views_day  min_views_day  \
# 0        4.348572       4.704214       4.007038
# 1        1.544461       1.874642       1.246771
# 2        1.142007       1.329981       0.968050
# 3        1.346100       1.541694       1.159259
# 4        1.510094       1.714514       1.319263
# 5        0.405191       0.752708       0.166475
# 6        0.409558       0.755197       0.162851
# 7        3.058433       3.340595       2.786301
# 8        0.363279       0.534056       0.225404
# 9        8.292344       8.689078       7.898546
# 10       1.816955       2.163122       1.492477
# 11       0.306061       0.549139       0.132371
# 12       0.305754       0.550649       0.130672
# 13       0.344586       0.599391       0.159103
# 14       0.732713       1.091877       0.440480
# 15       0.710810       0.943152       0.508665
# 16       1.091231       1.365591       0.844413
# 17       0.405154       0.529557       0.300271
# 18       0.064427       0.115318       0.027957
# 19       0.783065       1.009658       0.584349
# 20       0.398939       0.567771       0.258132
# 21       0.322029       0.442804       0.221035
# 22       0.286953       0.398323       0.194177
# 23       0.153333       0.237033       0.087914
# 24       0.280011       0.385938       0.190620
# 25       0.802864       0.971184       0.647166
# 26       0.430891       0.555385       0.321070
#
#                                              edit_url  days_active  \
# 0   https://www.etsy.com/your/shops/jetchcreations...    117.38736
# 1   https://www.etsy.com/your/shops/jetchcreations...     64.38736
# 2   https://www.etsy.com/your/shops/jetchcreations...    127.38736
# 3   https://www.etsy.com/your/shops/jetchcreations...    148.38736
# 4   https://www.etsy.com/your/shops/jetchcreations...    148.38736
# 5   https://www.etsy.com/your/shops/jetchcreations...     19.38736
# 6   https://www.etsy.com/your/shops/jetchcreations...     19.38736
# 7   https://www.etsy.com/your/shops/jetchcreations...    148.38736
# 8   https://www.etsy.com/your/shops/jetchcreations...     64.38736
# 9   https://www.etsy.com/your/shops/jetchcreations...    148.38736
# 10  https://www.etsy.com/your/shops/jetchcreations...     64.38736
# 11  https://www.etsy.com/your/shops/jetchcreations...     36.38736
# 12  https://www.etsy.com/your/shops/jetchcreations...     36.38736
# 13  https://www.etsy.com/your/shops/jetchcreations...     36.38736
# 14  https://www.etsy.com/your/shops/jetchcreations...     36.38736
# 15  https://www.etsy.com/your/shops/jetchcreations...     64.38736
# 16  https://www.etsy.com/your/shops/jetchcreations...     64.38736
# 17  https://www.etsy.com/your/shops/jetchcreations...    115.38736
# 18  https://www.etsy.com/your/shops/jetchcreations...    126.38736
# 19  https://www.etsy.com/your/shops/jetchcreations...     68.38736
# 20  https://www.etsy.com/your/shops/jetchcreations...     68.38736
# 21  https://www.etsy.com/your/shops/jetchcreations...    102.38736
# 22  https://www.etsy.com/your/shops/jetchcreations...    106.38736
# 23  https://www.etsy.com/your/shops/jetchcreations...    106.38736
# 24  https://www.etsy.com/your/shops/jetchcreations...    111.38736
# 25  https://www.etsy.com/your/shops/jetchcreations...    115.38736
# 26  https://www.etsy.com/your/shops/jetchcreations...    115.38736
#
#     curr_views_day
# 0         4.572830
# 1         1.637024
# 2         1.160479
# 3         1.372025
# 4         1.547339
# 5         0.099650
# 6         0.099650
# 7         3.178524
# 8         0.295848
# 9         8.689489
# 10        1.952595
# 11        0.105556
# 12        0.105556
# 13        0.158333
# 14        0.686111
# 15        0.690311
# 16        1.124221
# 17        0.376814
# 18        0.017252
# 19        0.775142
# 20        0.342505
# 21        0.281856
# 22        0.247110
# 23        0.102962
# 24        0.241362
# 25        0.799581
# 26        0.404386

# %%
bayes_df.sort_values(by='curr_views_day', ascending=False)
# Out:
#     listingID              creationDate  listingViews  totalSiteViews  \
# 9   680064082 2019-03-26 05:00:00-05:00          1140            3739
# 0   687898920 2019-04-26 05:00:00-05:00           499            3110
# 7   693930997 2019-03-26 05:00:00-05:00           417            3739
# 10  701339360 2019-06-18 05:00:00-05:00            99            1445
# 1   701341356 2019-06-18 05:00:00-05:00            83            1445
# 4   680079806 2019-03-26 05:00:00-05:00           203            3739
# 3   680071910 2019-03-26 05:00:00-05:00           180            3739
# 2   685451744 2019-04-16 05:00:00-05:00           136            3340
# 16  701202082 2019-06-18 05:00:00-05:00            57            1445
# 25  688465922 2019-04-28 05:00:00-05:00            87            3101
# 19  700382982 2019-06-14 05:00:00-05:00            43            1581
# 15  701344590 2019-06-18 05:00:00-05:00            35            1445
# 14  707973152 2019-07-16 05:00:00-05:00            13             540
# 26  688443618 2019-04-28 05:00:00-05:00            44            3101
# 17  702303569 2019-04-28 05:00:00-05:00            41            3101
# 20  700377146 2019-06-14 05:00:00-05:00            19            1581
# 8   701210678 2019-06-18 05:00:00-05:00            15            1445
# 21  691796412 2019-05-11 05:00:00-05:00            26            2629
# 22  704569159 2019-05-07 05:00:00-05:00            24            2768
# 24  703387331 2019-05-02 05:00:00-05:00            25            2952
# 13  721874971 2019-07-16 05:00:00-05:00             3             540
# 12  721879701 2019-07-16 05:00:00-05:00             2             540
# 11  721881161 2019-07-16 05:00:00-05:00             2             540
# 23  690717354 2019-05-07 05:00:00-05:00            10            2768
# 6   712150418 2019-08-02 05:00:00-05:00             1             286
# 5   712179258 2019-08-02 05:00:00-05:00             1             286
# 18  685744834 2019-04-17 05:00:00-05:00             2            3304
#
#     avg_views_day  max_views_day  min_views_day  \
# 9        8.292344       8.689078       7.898546
# 0        4.348572       4.704214       4.007038
# 7        3.058433       3.340595       2.786301
# 10       1.816955       2.163122       1.492477
# 1        1.544461       1.874642       1.246771
# 4        1.510094       1.714514       1.319263
# 3        1.346100       1.541694       1.159259
# 2        1.142007       1.329981       0.968050
# 16       1.091231       1.365591       0.844413
# 25       0.802864       0.971184       0.647166
# 19       0.783065       1.009658       0.584349
# 15       0.710810       0.943152       0.508665
# 14       0.732713       1.091877       0.440480
# 26       0.430891       0.555385       0.321070
# 17       0.405154       0.529557       0.300271
# 20       0.398939       0.567771       0.258132
# 8        0.363279       0.534056       0.225404
# 21       0.322029       0.442804       0.221035
# 22       0.286953       0.398323       0.194177
# 24       0.280011       0.385938       0.190620
# 13       0.344586       0.599391       0.159103
# 12       0.305754       0.550649       0.130672
# 11       0.306061       0.549139       0.132371
# 23       0.153333       0.237033       0.087914
# 6        0.409558       0.755197       0.162851
# 5        0.405191       0.752708       0.166475
# 18       0.064427       0.115318       0.027957
#
#                                              edit_url  days_active  \
# 9   https://www.etsy.com/your/shops/jetchcreations...    148.38736
# 0   https://www.etsy.com/your/shops/jetchcreations...    117.38736
# 7   https://www.etsy.com/your/shops/jetchcreations...    148.38736
# 10  https://www.etsy.com/your/shops/jetchcreations...     64.38736
# 1   https://www.etsy.com/your/shops/jetchcreations...     64.38736
# 4   https://www.etsy.com/your/shops/jetchcreations...    148.38736
# 3   https://www.etsy.com/your/shops/jetchcreations...    148.38736
# 2   https://www.etsy.com/your/shops/jetchcreations...    127.38736
# 16  https://www.etsy.com/your/shops/jetchcreations...     64.38736
# 25  https://www.etsy.com/your/shops/jetchcreations...    115.38736
# 19  https://www.etsy.com/your/shops/jetchcreations...     68.38736
# 15  https://www.etsy.com/your/shops/jetchcreations...     64.38736
# 14  https://www.etsy.com/your/shops/jetchcreations...     36.38736
# 26  https://www.etsy.com/your/shops/jetchcreations...    115.38736
# 17  https://www.etsy.com/your/shops/jetchcreations...    115.38736
# 20  https://www.etsy.com/your/shops/jetchcreations...     68.38736
# 8   https://www.etsy.com/your/shops/jetchcreations...     64.38736
# 21  https://www.etsy.com/your/shops/jetchcreations...    102.38736
# 22  https://www.etsy.com/your/shops/jetchcreations...    106.38736
# 24  https://www.etsy.com/your/shops/jetchcreations...    111.38736
# 13  https://www.etsy.com/your/shops/jetchcreations...     36.38736
# 12  https://www.etsy.com/your/shops/jetchcreations...     36.38736
# 11  https://www.etsy.com/your/shops/jetchcreations...     36.38736
# 23  https://www.etsy.com/your/shops/jetchcreations...    106.38736
# 6   https://www.etsy.com/your/shops/jetchcreations...     19.38736
# 5   https://www.etsy.com/your/shops/jetchcreations...     19.38736
# 18  https://www.etsy.com/your/shops/jetchcreations...    126.38736
#
#     curr_views_day
# 9         8.689489
# 0         4.572830
# 7         3.178524
# 10        1.952595
# 1         1.637024
# 4         1.547339
# 3         1.372025
# 2         1.160479
# 16        1.124221
# 25        0.799581
# 19        0.775142
# 15        0.690311
# 14        0.686111
# 26        0.404386
# 17        0.376814
# 20        0.342505
# 8         0.295848
# 21        0.281856
# 22        0.247110
# 24        0.241362
# 13        0.158333
# 12        0.105556
# 11        0.105556
# 23        0.102962
# 6         0.099650
# 5         0.099650
# 18        0.017252

# %%
bayes_test=[]

for index, item in bayes_df.iterrows():
    bayesDict={}
    bayesDict['a_listingID']=item[0]
    bayesDict['b_daysActive']=round(item[8],1)
    bayesDict['c_ListingVisits']=round(item[2],4)
    bayesDict['d_TotalSiteVisits']=round(item[3],4)
    bayesDict['e_CurrentVisitsDay']=round(item[9],4)
    bayesDict['f_AvgListingVisits']=round(item[4],4)
    bayesDict['g_MinListingVisits']=round(item[6],4)
    bayesDict['h_MaxListingVisits']=round(item[5],4)
    bayesDict['i_EditURL']=item[7]


    bayes_test.append(bayesDict)
bayes_test
# Out:
# [{'a_listingID': 687898920,
#   'b_daysActive': 117.4,
#   'c_ListingVisits': 499,
#   'd_TotalSiteVisits': 3110,
#   'e_CurrentVisitsDay': 4.5728,
#   'f_AvgListingVisits': 4.3486,
#   'g_MinListingVisits': 4.007,
#   'h_MaxListingVisits': 4.7042,
#   'i_EditURL': 'https://www.etsy.com/your/shops/jetchcreations/tools/listings/view:table,stats:true/687898920'},
#  {'a_listingID': 701341356,
#   'b_daysActive': 64.4,
#   'c_ListingVisits': 83,
#   'd_TotalSiteVisits': 1445,
#   'e_CurrentVisitsDay': 1.637,
#   'f_AvgListingVisits': 1.5445,
#   'g_MinListingVisits': 1.2468,
#   'h_MaxListingVisits': 1.8746,
#   'i_EditURL': 'https://www.etsy.com/your/shops/jetchcreations/tools/listings/view:table,stats:true/701341356'},
#  {'a_listingID': 685451744,
#   'b_daysActive': 127.4,
#   'c_ListingVisits': 136,
#   'd_TotalSiteVisits': 3340,
#   'e_CurrentVisitsDay': 1.1605,
#   'f_AvgListingVisits': 1.142,
#   'g_MinListingVisits': 0.968,
#   'h_MaxListingVisits': 1.33,
#   'i_EditURL': 'https://www.etsy.com/your/shops/jetchcreations/tools/listings/view:table,stats:true/685451744'},
#  {'a_listingID': 680071910,
#   'b_daysActive': 148.4,
#   'c_ListingVisits': 180,
#   'd_TotalSiteVisits': 3739,
#   'e_CurrentVisitsDay': 1.372,
#   'f_AvgListingVisits': 1.3461,
#   'g_MinListingVisits': 1.1593,
#   'h_MaxListingVisits': 1.5417,
#   'i_EditURL': 'https://www.etsy.com/your/shops/jetchcreations/tools/listings/view:table,stats:true/680071910'},
#  {'a_listingID': 680079806,
#   'b_daysActive': 148.4,
#   'c_ListingVisits': 203,
#   'd_TotalSiteVisits': 3739,
#   'e_CurrentVisitsDay': 1.5473,
#   'f_AvgListingVisits': 1.5101,
#   'g_MinListingVisits': 1.3193,
#   'h_MaxListingVisits': 1.7145,
#   'i_EditURL': 'https://www.etsy.com/your/shops/jetchcreations/tools/listings/view:table,stats:true/680079806'},
#  {'a_listingID': 712179258,
#   'b_daysActive': 19.4,
#   'c_ListingVisits': 1,
#   'd_TotalSiteVisits': 286,
#   'e_CurrentVisitsDay': 0.0997,
#   'f_AvgListingVisits': 0.4052,
#   'g_MinListingVisits': 0.1665,
#   'h_MaxListingVisits': 0.7527,
#   'i_EditURL': 'https://www.etsy.com/your/shops/jetchcreations/tools/listings/view:table,stats:true/712179258'},
#  {'a_listingID': 712150418,
#   'b_daysActive': 19.4,
#   'c_ListingVisits': 1,
#   'd_TotalSiteVisits': 286,
#   'e_CurrentVisitsDay': 0.0997,
#   'f_AvgListingVisits': 0.4096,
#   'g_MinListingVisits': 0.1629,
#   'h_MaxListingVisits': 0.7552,
#   'i_EditURL': 'https://www.etsy.com/your/shops/jetchcreations/tools/listings/view:table,stats:true/712150418'},
#  {'a_listingID': 693930997,
#   'b_daysActive': 148.4,
#   'c_ListingVisits': 417,
#   'd_TotalSiteVisits': 3739,
#   'e_CurrentVisitsDay': 3.1785,
#   'f_AvgListingVisits': 3.0584,
#   'g_MinListingVisits': 2.7863,
#   'h_MaxListingVisits': 3.3406,
#   'i_EditURL': 'https://www.etsy.com/your/shops/jetchcreations/tools/listings/view:table,stats:true/693930997'},
#  {'a_listingID': 701210678,
#   'b_daysActive': 64.4,
#   'c_ListingVisits': 15,
#   'd_TotalSiteVisits': 1445,
#   'e_CurrentVisitsDay': 0.2958,
#   'f_AvgListingVisits': 0.3633,
#   'g_MinListingVisits': 0.2254,
#   'h_MaxListingVisits': 0.5341,
#   'i_EditURL': 'https://www.etsy.com/your/shops/jetchcreations/tools/listings/view:table,stats:true/701210678'},
#  {'a_listingID': 680064082,
#   'b_daysActive': 148.4,
#   'c_ListingVisits': 1140,
#   'd_TotalSiteVisits': 3739,
#   'e_CurrentVisitsDay': 8.6895,
#   'f_AvgListingVisits': 8.2923,
#   'g_MinListingVisits': 7.8985,
#   'h_MaxListingVisits': 8.6891,
#   'i_EditURL': 'https://www.etsy.com/your/shops/jetchcreations/tools/listings/view:table,stats:true/680064082'},
#  {'a_listingID': 701339360,
#   'b_daysActive': 64.4,
#   'c_ListingVisits': 99,
#   'd_TotalSiteVisits': 1445,
#   'e_CurrentVisitsDay': 1.9526,
#   'f_AvgListingVisits': 1.817,
#   'g_MinListingVisits': 1.4925,
#   'h_MaxListingVisits': 2.1631,
#   'i_EditURL': 'https://www.etsy.com/your/shops/jetchcreations/tools/listings/view:table,stats:true/701339360'},
#  {'a_listingID': 721881161,
#   'b_daysActive': 36.4,
#   'c_ListingVisits': 2,
#   'd_TotalSiteVisits': 540,
#   'e_CurrentVisitsDay': 0.1056,
#   'f_AvgListingVisits': 0.3061,
#   'g_MinListingVisits': 0.1324,
#   'h_MaxListingVisits': 0.5491,
#   'i_EditURL': 'https://www.etsy.com/your/shops/jetchcreations/tools/listings/view:table,stats:true/721881161'},
#  {'a_listingID': 721879701,
#   'b_daysActive': 36.4,
#   'c_ListingVisits': 2,
#   'd_TotalSiteVisits': 540,
#   'e_CurrentVisitsDay': 0.1056,
#   'f_AvgListingVisits': 0.3058,
#   'g_MinListingVisits': 0.1307,
#   'h_MaxListingVisits': 0.5506,
#   'i_EditURL': 'https://www.etsy.com/your/shops/jetchcreations/tools/listings/view:table,stats:true/721879701'},
#  {'a_listingID': 721874971,
#   'b_daysActive': 36.4,
#   'c_ListingVisits': 3,
#   'd_TotalSiteVisits': 540,
#   'e_CurrentVisitsDay': 0.1583,
#   'f_AvgListingVisits': 0.3446,
#   'g_MinListingVisits': 0.1591,
#   'h_MaxListingVisits': 0.5994,
#   'i_EditURL': 'https://www.etsy.com/your/shops/jetchcreations/tools/listings/view:table,stats:true/721874971'},
#  {'a_listingID': 707973152,
#   'b_daysActive': 36.4,
#   'c_ListingVisits': 13,
#   'd_TotalSiteVisits': 540,
#   'e_CurrentVisitsDay': 0.6861,
#   'f_AvgListingVisits': 0.7327,
#   'g_MinListingVisits': 0.4405,
#   'h_MaxListingVisits': 1.0919,
#   'i_EditURL': 'https://www.etsy.com/your/shops/jetchcreations/tools/listings/view:table,stats:true/707973152'},
#  {'a_listingID': 701344590,
#   'b_daysActive': 64.4,
#   'c_ListingVisits': 35,
#   'd_TotalSiteVisits': 1445,
#   'e_CurrentVisitsDay': 0.6903,
#   'f_AvgListingVisits': 0.7108,
#   'g_MinListingVisits': 0.5087,
#   'h_MaxListingVisits': 0.9432,
#   'i_EditURL': 'https://www.etsy.com/your/shops/jetchcreations/tools/listings/view:table,stats:true/701344590'},
#  {'a_listingID': 701202082,
#   'b_daysActive': 64.4,
#   'c_ListingVisits': 57,
#   'd_TotalSiteVisits': 1445,
#   'e_CurrentVisitsDay': 1.1242,
#   'f_AvgListingVisits': 1.0912,
#   'g_MinListingVisits': 0.8444,
#   'h_MaxListingVisits': 1.3656,
#   'i_EditURL': 'https://www.etsy.com/your/shops/jetchcreations/tools/listings/view:table,stats:true/701202082'},
#  {'a_listingID': 702303569,
#   'b_daysActive': 115.4,
#   'c_ListingVisits': 41,
#   'd_TotalSiteVisits': 3101,
#   'e_CurrentVisitsDay': 0.3768,
#   'f_AvgListingVisits': 0.4052,
#   'g_MinListingVisits': 0.3003,
#   'h_MaxListingVisits': 0.5296,
#   'i_EditURL': 'https://www.etsy.com/your/shops/jetchcreations/tools/listings/view:table,stats:true/702303569'},
#  {'a_listingID': 685744834,
#   'b_daysActive': 126.4,
#   'c_ListingVisits': 2,
#   'd_TotalSiteVisits': 3304,
#   'e_CurrentVisitsDay': 0.0173,
#   'f_AvgListingVisits': 0.0644,
#   'g_MinListingVisits': 0.028,
#   'h_MaxListingVisits': 0.1153,
#   'i_EditURL': 'https://www.etsy.com/your/shops/jetchcreations/tools/listings/view:table,stats:true/685744834'},
#  {'a_listingID': 700382982,
#   'b_daysActive': 68.4,
#   'c_ListingVisits': 43,
#   'd_TotalSiteVisits': 1581,
#   'e_CurrentVisitsDay': 0.7751,
#   'f_AvgListingVisits': 0.7831,
#   'g_MinListingVisits': 0.5843,
#   'h_MaxListingVisits': 1.0097,
#   'i_EditURL': 'https://www.etsy.com/your/shops/jetchcreations/tools/listings/view:table,stats:true/700382982'},
#  {'a_listingID': 700377146,
#   'b_daysActive': 68.4,
#   'c_ListingVisits': 19,
#   'd_TotalSiteVisits': 1581,
#   'e_CurrentVisitsDay': 0.3425,
#   'f_AvgListingVisits': 0.3989,
#   'g_MinListingVisits': 0.2581,
#   'h_MaxListingVisits': 0.5678,
#   'i_EditURL': 'https://www.etsy.com/your/shops/jetchcreations/tools/listings/view:table,stats:true/700377146'},
#  {'a_listingID': 691796412,
#   'b_daysActive': 102.4,
#   'c_ListingVisits': 26,
#   'd_TotalSiteVisits': 2629,
#   'e_CurrentVisitsDay': 0.2819,
#   'f_AvgListingVisits': 0.322,
#   'g_MinListingVisits': 0.221,
#   'h_MaxListingVisits': 0.4428,
#   'i_EditURL': 'https://www.etsy.com/your/shops/jetchcreations/tools/listings/view:table,stats:true/691796412'},
#  {'a_listingID': 704569159,
#   'b_daysActive': 106.4,
#   'c_ListingVisits': 24,
#   'd_TotalSiteVisits': 2768,
#   'e_CurrentVisitsDay': 0.2471,
#   'f_AvgListingVisits': 0.287,
#   'g_MinListingVisits': 0.1942,
#   'h_MaxListingVisits': 0.3983,
#   'i_EditURL': 'https://www.etsy.com/your/shops/jetchcreations/tools/listings/view:table,stats:true/704569159'},
#  {'a_listingID': 690717354,
#   'b_daysActive': 106.4,
#   'c_ListingVisits': 10,
#   'd_TotalSiteVisits': 2768,
#   'e_CurrentVisitsDay': 0.103,
#   'f_AvgListingVisits': 0.1533,
#   'g_MinListingVisits': 0.0879,
#   'h_MaxListingVisits': 0.237,
#   'i_EditURL': 'https://www.etsy.com/your/shops/jetchcreations/tools/listings/view:table,stats:true/690717354'},
#  {'a_listingID': 703387331,
#   'b_daysActive': 111.4,
#   'c_ListingVisits': 25,
#   'd_TotalSiteVisits': 2952,
#   'e_CurrentVisitsDay': 0.2414,
#   'f_AvgListingVisits': 0.28,
#   'g_MinListingVisits': 0.1906,
#   'h_MaxListingVisits': 0.3859,
#   'i_EditURL': 'https://www.etsy.com/your/shops/jetchcreations/tools/listings/view:table,stats:true/703387331'},
#  {'a_listingID': 688465922,
#   'b_daysActive': 115.4,
#   'c_ListingVisits': 87,
#   'd_TotalSiteVisits': 3101,
#   'e_CurrentVisitsDay': 0.7996,
#   'f_AvgListingVisits': 0.8029,
#   'g_MinListingVisits': 0.6472,
#   'h_MaxListingVisits': 0.9712,
#   'i_EditURL': 'https://www.etsy.com/your/shops/jetchcreations/tools/listings/view:table,stats:true/688465922'},
#  {'a_listingID': 688443618,
#   'b_daysActive': 115.4,
#   'c_ListingVisits': 44,
#   'd_TotalSiteVisits': 3101,
#   'e_CurrentVisitsDay': 0.4044,
#   'f_AvgListingVisits': 0.4309,
#   'g_MinListingVisits': 0.3211,
#   'h_MaxListingVisits': 0.5554,
#   'i_EditURL': 'https://www.etsy.com/your/shops/jetchcreations/tools/listings/view:table,stats:true/688443618'}]

# %%
bayes_df.columns
# Out:
# Index(['listingID', 'creationDate', 'listingViews', 'totalSiteViews',
#        'avg_views_day', 'max_views_day', 'min_views_day', 'edit_url',
#        'days_active', 'curr_views_day'],
#       dtype='object')

# %% [markdown]
# # Test for Single Item

# %%
test_listingIDs= 721881161
stats_by_listing=listing_stats_df.loc[listing_stats_df['listingID']==test_listingIDs,:]
stats_by_listing.head()
# Out:
#       listingID record_date  revenue  sold  visits          record_date_local
# 2265  721881161     7/16/19      0.0     0       0  2019-07-16 05:00:00-05:00
# 2296  721881161     7/17/19      0.0     0       0  2019-07-17 05:00:00-05:00
# 2327  721881161     7/18/19      0.0     0       0  2019-07-18 05:00:00-05:00
# 2358  721881161     7/19/19      0.0     0       0  2019-07-19 05:00:00-05:00
# 2390  721881161     7/20/19      0.0     0       0  2019-07-20 05:00:00-05:00

# %%
listingViews = stats_by_listing['visits'].sum()
listingViews
# Out:
# 2

# %%
creation_date_by_listings=listing_creation_df.loc[listing_creation_df['ListingID']==test_listingIDs,:]
creation_date_by_listings
# Out:
#     ListingID OriginallyCreated
# 25  721881161        2019-07-16

# %%
creation_date_by_listings=creation_date_by_listings.reset_index(drop=True)
creationDate=creation_date_by_listings['OriginallyCreated'][0]
creationDate
# Out:
# Timestamp('2019-07-16 00:00:00')

# %%
total_views_since_creation=listing_stats_df.loc[listing_stats_df['date']>=creationDate]
total_views_since_creation.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-e24c9a71e946> in <module>
# ----> 1 total_views_since_creation=listing_stats_df.loc[listing_stats_df['date']>=creationDate]
#       2 total_views_since_creation.head()
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'

# %%
totalSiteViews = total_views_since_creation['visits'].sum()
totalSiteViews
